# %% [markdown]
# # Dependencies

# %%
import numpy as np
import pandas as pd
import csv
import os
import math

import Inputs as ip

# %% [markdown]
# # Description of Parameters

# %% [markdown]
# ***Double click here for better formatting***
#
# def main(shape='d',           #See options for shape
#          length=3.4,          #Main tube length (cm)
#          thickness=25,        #Foil thickness (µm)
#          number=470,          #Number of foils
#          TARGET='test.txt',   #file path/name for target (e.g., './KW-10.t')
#          temp=2300,           #global temperature
#          mass=8,              #mass (8 for 8Li)
#          Nmax=1000,           #number of histories for the Source card
#          height=0.525,        #D-shaped
#          rotate=0,            #rotation of foils (typically between 0-30)
#          ionizer=5.956,       #ionizer length (cm)
#          gradient=None,       #temperature gradient (K) to be used for the ionizer
#          m=1,                 #slope of line for symmetrical cutout OR horseshoe design
#          r1=0.9144,           #horseshoe OR cylinder exterior radius
#          r2=0.3644,           #horseshoe OR cylinder interior radius
#          th=np.pi/4,          #angle of symm/horse cut line (rel. to outer circle for symm, inner for horse)
#          sep_loc='Single',    #cylinder: location of separation
#                               #'Single','Left' or 'Side','Centre' or 'Center' or 'Middle'
#          sep=0,               #length of region between cylinders
#          hsep=0,              #length of region for horseshoes wrt doughnuts
#          squish=1             #percentage of target length to contain foils ('squish factor')
#     ):
# #Options for shape
#     d_list = ['D','d','D-shaped','d-shaped']
#     s_list = ['symm','Symm']
#     h_list = ['Donut','donut','doughnut','Doughnut','ring','Ring']
#     lc_list = ['C-Long','c-long','c-longitudinal','C-Longitudinal'] #CERN longitudinal

# %% [markdown]
# # Template

# %%
#[Description of run]
#Rotated D-foils
DIR = '../targets/D-ROT'
try: 
    os.mkdir(DIR)
except OSError as error:
    print(error) 
    if error.args[0] == 17:
        print('Directory already exists. Files may be overwritten if the same filenames are used.')
#[Lists of parameters to be iterated over]
nuc = ['Li8','Be14']
masses = [8,14]
ang = [0,10*np.pi/180,20*np.pi/180]
a2 = [0,10,20]
ion = [4.1253,5.956]
#[loop(s) that create the target files]
for ii in ion: 
    #[for ionizer lengths, I'm changing the dots to underscores for better file name clarity]
    st = str(round(ii,4))
    st = st.replace('.','_')
    for nn,mm in zip(nuc,masses):
        for aa in ang:
            a2 = str(round(aa*180/np.pi))
            ip.main(TARGET=DIR+'/KW-'+nn+'-'+a2+'-'+st+'.t',
                 Nmax=500,shape='D',number=470,ionizer=ii,mass=mm,rotate=aa)
#flag for when it's finished running
print('Done!')
# Out:
# [Errno 17] File exists: './targets/D-ROT'
# Directory already exists. Files may be overwritten if the same filenames are used.
# Done!

# %% [markdown]
# # Archive

# %%
#calling the things!
'__________________________________________________________________________________________________________'
#******SQUISH
# length = 3.4
# thickness = 25*1e-4
# num = 10
# #gaps = (length*squish-(number*thickness*1e-4)-sep)/(number+1)
# g = (length-(num*thickness))/(num+1)
# print(g)
# gaps = np.linspace(1e-5,g,5)
# print(gaps)
# sq1 = (gaps*(num+1)+num*thickness)/length
# print(sq1)

# for sq in sq1:
#     st = str(round(sq,3))
#     st = st.replace('.','_')
#     print(st)
#     main(TARGET='Squish/KW-D-10SQ-'+str(st)+'.t',Nmax=1000,number=10,shape='D',squish=sq)
'__________________________________________________________________________________________________________'
# for nn,mm in zip(nuc,masses):
#     main(TARGET='../targets/Shapes/KW-Pizza-'+nn+'-20.t',Nmax=500,shape='symm',
#          mass=mm,length=3.031576, #length is different since we want the same gap as D shaped
#          m=1,th=np.pi/6,number=419,rotate=-20*np.pi/180)
# '__________________________________________________________________________________________________________'
# *********Varying ionizer length (D-470) w/ rot
# try: 
#     os.mkdir('../targets/D-ROT')
# except OSError as error:
#     print(error)  
#     print('Don\'t worry; things are still running smoothly :)')
# nuc = ['Li8','Be14']
# masses = [8,14]
# ang = [0,-10*np.pi/180,-20*np.pi/180]
# ion = [4.1253,5.956]
# for ii in ion: 
#     st = str(round(ii,4))
#     st = st.replace('.','_')
#     for nn,mm in zip(nuc,masses):
#         for aa in ang:
#             a2 = str(round(aa*180/np.pi))
#             main(TARGET='../targets/D-ROT/KW-'+nn+'-'+a2+'-'+st+'.t',
#                  Nmax=500,shape='D',number=470,ionizer=ii,mass=mm,rotate=aa)

'__________________________________________________________________________________________________________'
#********JUST IONIZER            
# nuc = ['Li8','Li11','Be12','Be14']
# masses = [8,11,12,14]
# ang = [0,np.pi/6,np.pi/4]
# ion = np.linspace(1.3792,5.956*2-1.3792,11)
# for ii in ion[:-3]: 
#     st = str(round(ii,4))
#     st = st.replace('.','_')
#     for nn,mm in zip(nuc,masses):
#         main(TARGET='../targets/ionizer/KW-'+nn+'-'+st+'.t',
#              Nmax=500,shape='ion',ionizer=ii,mass=mm)
'__________________________________________________________________________________________________________'
#********Varying thickness
# thicc = [2,12.5]
# length = [28.93809808917197,5.620276008492568,3.4,2.289861995753715]
# number = [5876,940,470,235]
# for x,y,z in zip(thicc,length,number):
#     st = str(x)
#     st = st.replace('.','_')
#     for nn,mm in zip(nuc,masses):
#         main(TARGET='../targets/Thick/KW-'+nn+'-'+st+'.t',Nmax=500,shape='D',mass=mm,
#              thickness=x,number=z)
#****************Updated (in use)
# for nn,mm in zip(nuc,masses):
#     for ii in [4.1253,5.956]: 
#         st = str(round(ii,4))
#         st = st.replace('.','_')
#         main(TARGET='../targets/Thick/KW-'+nn+'-'+st+'.t',Nmax=500,shape='D',mass=mm,     
#              thickness=2,number=689,ionizer=ii)
#***run 5
# try: 
#     os.mkdir('../targets/Thick5')
# except OSError as error:
#     print(error)  
#     print('Don\'t worry; things are still running smoothly :)')
# for nn,mm in zip(nuc,masses):
#     for ii in [4.1253,5.956]: 
#         st = str(round(ii,4))
#         st = st.replace('.','_')
#         main(TARGET='../targets/Thick5/KW-'+nn+'-'+st+'.t',Nmax=500,shape='D',mass=mm,     
#              length=28.92825010615711,thickness=2,number=5874,ionizer=ii)
# #***run 6
# try: 
#     os.mkdir('../targets/Thick6')
# except OSError as error:
#     print(error)  
#     print('Don\'t worry; things are still running smoothly :)')
# for nn,mm in zip(nuc,masses):
#     for ii in [4.1253,5.956]: 
#         st = str(round(ii,4))
#         st = st.replace('.','_')
#         main(TARGET='../targets/Thick6/KW-'+nn+'-'+st+'.t',Nmax=500,shape='D',mass=mm,     
#              length=6.618044585987259,thickness=2,number=1345,ionizer=ii)
'__________________________________________________________________________________________________________'

# #****run 7 (arc)
# try: 
#     os.mkdir('../targets/Arc')
# except OSError as error:
#     print(error)  
#     print('Don\'t worry; things are still running smoothly :)')
# for nn,mm in zip(nuc,masses):
#     for ii in [4.1253,5.956]: 
#         st = str(round(ii,4))
#         st = st.replace('.','_')
#         main(TARGET='../targets/Arc/KW-'+nn+'-'+st+'.t',Nmax=500,shape='arc',mass=mm,     
#              number=450,ionizer=ii)

'__________________________________________________________________________________________________________'

#*****run 8 (ionizer w/ gradient)
# try: 
#     os.mkdir('../targets/Gradient-Ion')
# except OSError as error:
#     print(error)  
#     print('Don\'t worry; things are still running smoothly :)')
# gradient = {}
# gradient[4.1253] = []
# gradient[5.956]  = []
# for nn,mm in zip(nuc,masses):
#     for ii in [4.1253,5.956]: 
#         st = str(round(ii,4))
#         st = st.replace('.','_')
#         main(TARGET='../targets/Gradient-Ion/KW-'+nn+'-'+st+'.t',Nmax=500,shape='ion',mass=mm,     
#              ionizer=ii,gradient=gradient[ii])
'__________________________________________________________________________________________________________'
#*****run 9 (ionizer at 1250K)           
# try: 
#     os.mkdir('../targets/1250K')
# except OSError as error:
#     print(error)  
#     print('Don\'t worry; things are still running smoothly :)')

# nuc = ['Li8','Li11','Be12','Be14']
# masses = [8,11,12,14]
# for ii in [3.2099,4.1253,5.956]: 
#     st = str(round(ii,4))
#     st = st.replace('.','_')
#     for nn,mm in zip(nuc,masses):
#         main(TARGET='../targets/1250K/KW-'+nn+'-'+st+'.t',
#              Nmax=500,shape='ion',ionizer=ii,mass=mm,
#              temp=1250)
'__________________________________________________________________________________________________________'
#****run 10 (standard w/ +20˚ rotation)
# try: 
#     os.mkdir('../targets/D20')
# except OSError as error:
#     print(error)  
#     print('Don\'t worry; things are still running smoothly :)')
# nuc = ['Li8','Be14']
# masses = [8,14]
# ang = [15*np.pi/180,25*np.pi/180,30*np.pi/180]#[0,10*np.pi/180,20*np.pi/180]
# ion = [4.1253,5.956]
# for ii in ion: 
#     st = str(round(ii,4))
#     st = st.replace('.','_')
#     for nn,mm in zip(nuc,masses):
#         for aa in ang:
#             a2 = str(round(aa*180/np.pi))
#             main(TARGET='../targets/D20/KW-'+nn+'-'+a2+'-'+st+'.t',
#                  Nmax=500,shape='D',number=470,ionizer=ii,mass=mm,rotate=aa)
'__________________________________________________________________________________________________________'

# try: 
#     os.mkdir('../targets/thin foils')
# except OSError as error:
#     print(error)  
#     print('Don\'t worry; things are still running smoothly :)')
# nuc = ['Li8','Be14']
# masses = [8,14]
# ion = [4.1253,5.956]
# for ii in ion: 
#     st = str(round(ii,4))
#     st = st.replace('.','_')
#     for nn,mm in zip(nuc,masses):
#         main(TARGET='../targets/thin foils/KW-'+nn+'-'+st+'.t',
#              Nmax=500,shape='D',number=470,ionizer=ii,mass=mm,rotate=aa)

'__________________________________________________________________________________________________________'

# nuc = ['Li8','Li11','Be12','Be14']
# masses = [8,11,12,14]
# #*******arc
# try: 
#     os.mkdir('../targets/Arc')
# except OSError as error:
#     print(error)  
#     print('Don\'t worry; things are still running smoothly :)')
# for nn,mm in zip(nuc,masses):
#     for ii in [4.1253,5.956]: 
#         st = str(round(ii,4))
#         st = st.replace('.','_')
#         main(TARGET='../targets/Arc/KW-'+nn+'-'+st+'.t',Nmax=500,shape='arc',mass=mm,
#              ionizer=ii)

'__________________________________________________________________________________________________________'

print('Done!')
